# %% [markdown]
# <a href="https://colab.research.google.com/github/kokilasri/Breast-Cancer-Prediction/blob/main/python_beginner_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # WORD GUESS GAME

# %%
import pandas as pd
import random

df = pd.read_csv('words.txt')

name = input('Enter your name: ')
print('*** WELCOME TO WORD FINDER GAME ***')

print("\n\n INSTRUCTIONS \n  ")
print("hi {0}, Let's start the Game ".format(name))
print('You have 5 chances to find the word')
print('you have 5 turns to guess the word ')

turns = 10
actword  = random.choice(df.Words)
l = len(actword)
guessed_word = []
wrong_word = []



print('\n\n GAME STARTED - GOOD LUCK {0} '.format(name))
print('your have to find the word of length {0} '.format(l))
for i in range(l):
    guessed_word.append('_ ')
print(guessed_word)
print('\n')
guess = ""

while turns>0:
    guessed_letter = input('Enter your Guess: ')
    print('\n')

    if not guessed_letter.isalpha():
        print('Guess only a letter\n')
        continue
    elif len(guessed_letter) > 1:
        print('Guess only one letter\n')
        continue
    elif (guessed_letter in wrong_word):
        print("You have already guessed the letter\n")
        continue

    if guessed_letter in actword:
        print('you have guessed the correct letter')
        for i in range(l):
            if (actword[i] == guessed_letter):
                guessed_word[i] = actword[i]
        print("\n", guessed_word)
    
    else:
        print('you have guessed the wrong letter')
        turns = turns - 1
        print("you have only {0} turns left ".format(turns))
        print('\n')
        wrong_word.append(guessed_letter)

    guess = "".join(guessed_word)
    if (guess == actword):
        print("YAYYYYY !! YOU HAVE WON THE GAME")
        print(" The correct answer is {0} ". format(actword))
        break

if (turns == 0):
    print(" The correct answer is {0} ". format(actword))
    print("\n SORRY, YOU HAVE LOST THE GAME")
# Out:
# Enter your name: Radha
# *** WELCOME TO WORD FINDER GAME ***
#
#
#  INSTRUCTIONS
#
# hi Radha, Let's start the Game
# You have 5 chances to find the word
# you have 5 turns to guess the word
#
#
#  GAME STARTED - GOOD LUCK Radha
# your have to find the word of length 7
# ['_ ', '_ ', '_ ', '_ ', '_ ', '_ ', '_ ']
#
#
# Enter your Guess: a
#
#
# you have guessed the correct letter
#
#  ['_ ', 'a', '_ ', '_ ', '_ ', 'a', '_ ']
# Enter your Guess: k
#
#
# you have guessed the wrong letter
# you have only 9 turns left
#
#
# Enter your Guess: e
#
#
# you have guessed the wrong letter
# you have only 8 turns left
#
#
# Enter your Guess: i
#
#
# you have guessed the wrong letter
# you have only 7 turns left
#
#
# Enter your Guess: h
#
#
# you have guessed the wrong letter
# you have only 6 turns left
#
#
# Enter your Guess: m
#
#
# you have guessed the wrong letter
# you have only 5 turns left
#
#
# Enter your Guess: t
#
#
# you have guessed the correct letter
#
#  ['_ ', 'a', 't', '_ ', '_ ', 'a', '_ ']
# Enter your Guess: e
#
#
# You have already guessed the letter
#
# Enter your Guess: 8
#
#
# Guess only a letter
#
# Enter your Guess: ty
#
#
# Guess only one letter
#
# Enter your Guess: n
#
#
# you have guessed the correct letter
#
#  ['n', 'a', 't', '_ ', '_ ', 'a', '_ ']
# Enter your Guess: l
#
#
# you have guessed the correct letter
#
#  ['n', 'a', 't', '_ ', '_ ', 'a', 'l']
# Enter your Guess: u
#
#
# you have guessed the correct letter
#
#  ['n', 'a', 't', 'u', '_ ', 'a', 'l']
# Enter your Guess: r
#
#
# you have guessed the correct letter
#
#  ['n', 'a', 't', 'u', 'r', 'a', 'l']
# YAYYYYY !! YOU HAVE WON THE GAME
